# %%
import pandas as pd
import numpy as np

# %%
data="F:\streamlit project\Emigrants Data (1981-2023).xlsx"
df=pd.read_excel(data,sheet_name="Country Wise")

df.groupby(by=["Destination Region"])["Destination Country"].unique()
df.head()
df.columns
# Out:
# Index(['Origin Country', 'Origin Country Latitude', 'Origin Country Longitude',
#        'Destination Region', 'Destination Country', 'Dest. Country Latitude',
#        'Dest. Country Longitude', 'Year', 'No. of Emigrants'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Origin Country            2240 non-null   object
#  1   Origin Country Latitude   2240 non-null   float64
#  2   Origin Country Longitude  2240 non-null   float64
#  3   Destination Region        2240 non-null   object
#  4   Destination Country       2240 non-null   object
#  5   Dest. Country Latitude    2227 non-null   float64
#  6   Dest. Country Longitude   2227 non-null   float64
#  7   Year                      2240 non-null   int64
#  8   No. of Emigrants          2240 non-null   int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 157.6+ KB

# %%
data="Emigrants Data (1981-2023).xlsx"
df=pd.read_excel(data,sheet_name="District Wise")
df.head()
# Out:
#              Province   Districts   Latitude  Longitude  Year  \
# 0  Khyber Pakhtunkhwa  Abbottabad  34.149503  73.199501  1981
# 1  Khyber Pakhtunkhwa  Abbottabad  34.149503  73.199501  1982
# 2  Khyber Pakhtunkhwa  Abbottabad  34.149503  73.199501  1983
# 3  Khyber Pakhtunkhwa  Abbottabad  34.149503  73.199501  1984
# 4  Khyber Pakhtunkhwa  Abbottabad  34.149503  73.199501  1985
#
#    No. of Emigrants
# 0              2494
# 1              2241
# 2              1956
# 3              1524
# 4              1342

# %%
data="Emigrants Data (1981-2023).xlsx"
df=pd.read_excel(data,sheet_name="Skill Level")
df.head()
# Out:
#    Year         Skill-Level  No. of Emigrants
# 0  1981  Highly  Qualified               2467
# 1  1981     Highly Skilled               6984
# 2  1981            Skilled              60503
# 3  1981       Semi Skilled               2707
# 4  1981         Un-Skilled              80420

# %%
data="Emigrants Data (1981-2023).xlsx"
df=pd.read_excel(data,sheet_name="Province_Wise")
df.head()
# Out:
#    Year            Province   Latitude  Longitude  No. of Emigrants
# 0  1981             FEDERAL  33.738045  73.084488                23
# 1  1981              PUNJAB  31.170406  72.709716             75506
# 2  1981               SINDH  25.894302  68.524715             22800
# 3  1981  KHYBER PAKHTUNKHWA  34.952621  72.331113             38485
# 4  1981         BALOCHISTAN  28.490733  65.095779              1755

# %%
df["Province"].value_counts()
# Out:
# Province
# FEDERAL               43
# PUNJAB                43
# SINDH                 43
# KHYBER PAKHTUNKHWA    43
# BALOCHISTAN           43
# AZAD KASHMIR          43
# NORTHERN AREAS        43
# TRIBAL AREA           43
# Name: count, dtype: int64

# %%
data="Emigrants Data (1981-2023).xlsx"
df=pd.read_excel(data,sheet_name="Profession")
df.head()
# Out:
#    Profession  Year  No. of Emigrants
# 0  Accountant  1981               603
# 1  Accountant  1982               542
# 2  Accountant  1983               473
# 3  Accountant  1984               368
# 4  Accountant  1985               324

# %%
# %pip install dash
# Out:
# ...
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
# ...

# %%
# %pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
